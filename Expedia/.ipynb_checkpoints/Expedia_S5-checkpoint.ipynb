# %%
import pandas as pd
import numpy as np

data = pd.read_csv('expedia_data.csv')

# מיון הנתונים
sorted_df = data.sort_values(by=['Snapshot Date', 'TTT', 'LOS'])

# הוספת שדה חדש 'new_order' לסידור הנתונים
current_los = None
page = 0
pages_list = []
new_order = 0
new_order_list = []

for index, row in sorted_df.iterrows():
    if row['LOS'] != current_los:
        page += 1 
        new_order = 1
        current_los = row['LOS']
    else:
        new_order += 1
    new_order_list.append(new_order)
    pages_list.append(page)

sorted_df['new_order'] = new_order_list
sorted_df['page_num'] = pages_list

data = sorted_df.drop(['order'], axis=1)

# שמירת הנתונים לקובץ CSV
data.to_csv('expedia_data_sorted.csv', index=False)

# הורדת עמודות מיותרות
data = data.drop(['name', 'checkin_date' ,'checkout_date', 'Snapshot Date'], axis=1)

# %%
# חלוקת הנתונים לפי מספרי עמודים זוגיים ואי זוגיים
train_data = data[data['TTT'] % 2 == 0]
test_data = data[data['TTT'] % 2 != 0]

# בחירת עמודות מספריות בלבד, למעט new_order ו-page_num
numeric_columns = train_data.select_dtypes(include=[np.number]).columns.tolist()
numeric_columns.remove('new_order')
numeric_columns.remove('page_num')

# %%
from sklearn.preprocessing import StandardScaler

def create_pairs(data, numeric_columns, num_pairs=100):
    pairs = []  # רשימה לאחסון הזוגות
    pages = data['page_num'].unique()  # רשימה של כל העמודים הייחודיים

    scaler = StandardScaler()
    data[numeric_columns] = scaler.fit_transform(data[numeric_columns])
    
    # עבור כל עמוד
    for page in pages:
        page_data = data[data['page_num'] == page]  # נתונים של העמוד הנוכחי
        indices = page_data.index.values  # אינדקסים של השורות בעמוד הנוכחי

        # בדיקה אם יש מספיק מלונות ליצירת זוגות
        if len(indices) < 2:
            continue

        # יצירת מספר קבוע של זוגות אקראיים
        for _ in range(num_pairs):
            idx_a, idx_b = np.random.choice(indices, size=2, replace=False)  # בחירת שני אינדקסים אקראיים
            hotel_a_features = page_data.loc[idx_a, numeric_columns].values  # מאפייני מלון א
            hotel_b_features = page_data.loc[idx_b, numeric_columns].values  # מאפייני מלון ב

            # הקלסיפיקציה היא 1 אם מלון א מדורג גבוה יותר, -1 אם מלון ב מדורג גבוה יותר
            classification = 1 if page_data.loc[idx_a]['new_order'] < page_data.loc[idx_b]['new_order'] else -1

            # הוספת הזוג לרשימה
            pairs.append({
                'hotel_a_features': hotel_a_features,
                'hotel_b_features': hotel_b_features,
                'classification': classification,
                'idx_a': idx_a,
                'idx_b': idx_b
            })

    # החזרת הנתונים כ-DataFrame
    return pd.DataFrame(pairs)

# יצירת זוגות עבור קבוצת האימון
train_pairs = create_pairs(train_data, numeric_columns)
# Out:
# C:\Users\revit\AppData\Local\Temp\ipykernel_17812\1206910376.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[numeric_columns] = scaler.fit_transform(data[numeric_columns])

# %%
from sklearn.tree import DecisionTreeRegressor
def prepare_weighted_training_data(pairs, important_features, feature_importance):
    X = []  # רשימה לאחסון הפרשי המאפיינים בין המלונות
    y = []  # רשימה לאחסון הקלסיפיקציה (1 או -1)
    
    for _, row in pairs.iterrows():
        hotel_a_features = pd.Series(row['hotel_a_features'], index=numeric_columns).loc[important_features].values
        hotel_b_features = pd.Series(row['hotel_b_features'], index=numeric_columns).loc[important_features].values
        
        # חישוב הפרשי המאפיינים בין מלון א למלון ב ושקלול לפי חשיבות הפיצ'רים
        diff_features = (hotel_a_features - hotel_b_features) * feature_importance
        X.append(diff_features)
        y.append(row['classification'])
    
    return np.array(X), np.array(y)

# אימון מודל עץ החלטה לחישוב חשיבות הפיצ'רים
tree_model = DecisionTreeRegressor()
X_train_base, y_train_base = prepare_weighted_training_data(train_pairs, numeric_columns, np.ones(len(numeric_columns)))
tree_model.fit(X_train_base, y_train_base)
feature_importance = tree_model.feature_importances_

# הדפסת חשיבות הפיצ'רים עם שמות הפיצ'רים
feature_importance_dict = {feature: importance for feature, importance in zip(numeric_columns, feature_importance)}
sorted_features = sorted(feature_importance_dict.items(), key=lambda item: item[1], reverse=True)
for feature, importance in sorted_features:
    print(f"{feature}: {importance}")

# בחירת 5 הפיצ'רים הכי חשובים
top_5_features = [feature for feature, importance in sorted_features[:5]]

# הכנת נתוני האימון עם שקלול לפי 5 הפיצ'רים הכי חשובים
top_5_feature_importance = [feature_importance_dict[feature] for feature in top_5_features]
X_train_weighted, y_train = prepare_weighted_training_data(train_pairs, top_5_features, top_5_feature_importance)
X_train_weighted
# Out:
# num_reviews: 0.2522017528288219
# price: 0.18460761611512402
# current_price: 0.18079569218502853
# price_after_taxes: 0.15184447670560847
# grade: 0.1050160477703409
# breakfast: 0.02966697615934285
# reserve_now_pay_later: 0.029608974075372725
# reviews_desc: 0.025778453277380046
# free_cancellation: 0.022837116380659644
# fully_refundable: 0.01764289450232103
# TTT: 0.0
# LOS: 0.0
# array([[-0.0007383607098221537, 0.0022114596617851126,
#         0.06771339404367466, 0.010130125191834144, 0.07297178034897084],
#        [-0.09327956967419884, 0.0011057298308925973, 0.05642782836972888,
#         0.005065062595917055, 0.0],
#        [-0.4703357721567123, 0.0005853863810607699, 0.06771339404367463,
#         0.002681503727250216, 0.07479607485769507],
#        ...,
#        [-0.003937923785718163, -0.17594112897437617,
#         -0.14445524062650592, -0.16118816849359627, 0.0],
#        [0.4152048391566582, -0.08358016662923229, -0.10382720420030112,
#         -0.07657182865592281, -0.18425374538115116],
#        [0.20600263804038108, -0.08488102525381176, -0.07674184658283126,
#         -0.07776360809025626, -0.10945767052345641]], dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier

# אימון מודל עץ החלטה על 5 הפיצ'רים החשובים בלבד
model_top5 = RandomForestClassifier()
X_train_top5, y_train = prepare_weighted_training_data(train_pairs, top_5_features, top_5_feature_importance)
model_top5.fit(X_train_top5, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.preprocessing import StandardScaler

# יצירת זוגות אקראיים עבור קבוצת הבדיקה
def create_test_pairs(data, numeric_columns, num_pairs=100):
    pairs = []
    pages = data['page_num'].unique()

    scaler = StandardScaler()
    data[numeric_columns] = scaler.fit_transform(data[numeric_columns])
    
    for page in pages:
        page_data = data[data['page_num'] == page]
        indices = page_data.index.values

        if len(indices) < 2:
            continue

        for _ in range(num_pairs):
            idx_a, idx_b = np.random.choice(indices, size=2, replace=False)
            hotel_a_features = page_data.loc[idx_a, numeric_columns].values
            hotel_b_features = page_data.loc[idx_b, numeric_columns].values
            
            if hotel_a_features.shape != hotel_b_features.shape:
                continue

            pairs.append({
                'page_num': page,
                'hotel_a_features': hotel_a_features,
                'hotel_b_features': hotel_b_features,
                'idx_a': idx_a,
                'idx_b': idx_b
            })

    return pd.DataFrame(pairs)

# חיזוי על זוגות הבדיקה
def predict_test_pairs(pairs, important_features, feature_importance, model_weighted, all_features):
    predictions = []

    for _, row in pairs.iterrows():
        hotel_a_features = pd.Series(row['hotel_a_features'], index=all_features)
        hotel_b_features = pd.Series(row['hotel_b_features'], index=all_features)
        
        hotel_a_features = hotel_a_features[important_features].values
        hotel_b_features = hotel_b_features[important_features].values

        diff_features = (hotel_a_features - hotel_b_features) * feature_importance

        # Ensure diff_features has the correct shape for the model
        diff_features = np.array(diff_features).reshape(1, -1)

        prediction = model_weighted.predict(diff_features)[0]
        predictions.append(prediction)

    pairs['prediction'] = predictions
    return pairs

# יצירת זוגות אקראיים עבור קבוצת הבדיקה
test_pairs = create_test_pairs(test_data, numeric_columns)
test_pairs = predict_test_pairs(test_pairs, top_5_features, top_5_feature_importance, model_top5, numeric_columns)

# מיון יציב של בתי המלון לפי התחזיות
def stable_sort_hotels(page_data, predictions):
    hotels = list(page_data['idx_a'].unique()) + list(page_data['idx_b'].unique())
    hotels = list(set(hotels))
    scores = {hotel: 0 for hotel in hotels}

    for _, row in predictions.iterrows():
        hotel_a = row['idx_a']
        hotel_b = row['idx_b']
        prediction = row['prediction']

        if prediction == 1:
            scores[hotel_a] += 1
        else:
            scores[hotel_b] += 1

    sorted_hotels = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    return [hotel for hotel, score in sorted_hotels]

# מיון בתי המלון בקבוצת הבדיקה
sorted_hotels = {}
for page in test_pairs['page_num'].unique():
    page_data = test_pairs[test_pairs['page_num'] == page]
    sorted_hotels[page] = stable_sort_hotels(page_data, page_data)

# הצגת התוצאות עבור עמוד אחד לדוגמה
sorted_hotels[list(sorted_hotels.keys())[0]]

# שמירת הנתונים לקובץ CSV
page_data.to_csv('expedia_sorted_hotels.csv', index=False)
# Out:
# C:\Users\revit\AppData\Local\Temp\ipykernel_17812\754252249.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[numeric_columns] = scaler.fit_transform(data[numeric_columns])

# %%
import numpy as np

def calculate_error(original_order, predicted_order):
    original_index = {hotel: idx for idx, hotel in enumerate(original_order)}
    predicted_index = {hotel: idx for idx, hotel in enumerate(predicted_order)}
    
    error = 0
    for hotel in original_order:
        if hotel in predicted_index:
            error += (original_index[hotel] - predicted_index[hotel])**2
    return error

errors = []

for page in test_data['page_num'].unique():
    # ביצוע שאפל אקראי של הנתונים בעמוד
    page_data = test_data[test_data['page_num'] == page].sample(frac=1).reset_index(drop=True)
    
    # יצירת זוגות אקראיים מחדש עם נרמול
    test_pairs_shuffled = create_test_pairs(page_data, numeric_columns)
    
    # ביצוע תחזיות על זוגות הבדיקה המשופעים
    test_pairs_shuffled = predict_test_pairs(test_pairs_shuffled, top_5_features, top_5_feature_importance, model_top5, numeric_columns)
    
    # מיון מחדש של בתי המלון בעמוד
    sorted_hotels_shuffled = stable_sort_hotels(test_pairs_shuffled, test_pairs_shuffled)
    sorted_hotels_shuffled
    # חישוב השגיאה עבור העמוד המשופע
    original_order = page_data.index.tolist()
    page_error = calculate_error(original_order, sorted_hotels_shuffled)
    errors.append(page_error)
    print(f'Error for page {page}: {page_error}')

mean_error = np.mean(errors)
std_error = np.std(errors)
print(sorted_hotels_shuffled)
print(f'Mean Error: {mean_error}')
print(f'Standard Deviation of Error: {std_error}')
# Out:
# Error for page 1: 215487
# Error for page 2: 212505
# Error for page 3: 247233
# Error for page 4: 192722
# Error for page 5: 156860
# Error for page 11: 251533
# Error for page 12: 208077
# Error for page 13: 179590
# Error for page 14: 265380
# Error for page 15: 168651
# Error for page 21: 255888
# Error for page 22: 248077
# Error for page 23: 168983
# Error for page 24: 207990
# Error for page 25: 185961
# Error for page 31: 212000
# Error for page 32: 199450
# Error for page 33: 252023
# Error for page 34: 238716
# Error for page 35: 216407
# Error for page 41: 231384
# Error for page 42: 229549
# Error for page 43: 217773
# Error for page 44: 221360
# Error for page 45: 171302
# Error for page 51: 209896
# Error for page 52: 276209
# Error for page 53: 107861
# Error for page 54: 227714
# Error for page 55: 152561
# Error for page 61: 243882
# Error for page 62: 246120
# Error for page 63: 177376
# Error for page 64: 216203
# Error for page 65: 221218
# Error for page 71: 234970
# Error for page 72: 207549
# Error for page 73: 234623
# Error for page 74: 261676
# Error for page 75: 223333
# Error for page 81: 273535
# Error for page 82: 258482
# Error for page 83: 221163
# Error for page 84: 239595
# Error for page 85: 173060
# Error for page 91: 278661
# Error for page 92: 236351
# Error for page 93: 209919
# Error for page 94: 165320
# Error for page 95: 186271
# Error for page 101: 183268
# Error for page 102: 233545
# Error for page 103: 206696
# Error for page 104: 223577
# Error for page 105: 216429
# Error for page 111: 104118
# Error for page 112: 246228
# Error for page 113: 204949
# Error for page 114: 244379
# Error for page 115: 199538
# Error for page 121: 199894
# Error for page 122: 211498
# Error for page 123: 237757
# Error for page 124: 195447
# Error for page 125: 142333
# Error for page 131: 219693
# Error for page 132: 214458
# Error for page 133: 154473
# Error for page 134: 222544
# Error for page 135: 216630
# Error for page 141: 198060
# Error for page 142: 213057
# Error for page 143: 223179
# Error for page 144: 212384
# Error for page 145: 226365
# Error for page 156: 222339
# Error for page 157: 231273
# Error for page 158: 237487
# Error for page 159: 240701
# Error for page 160: 203901
# Error for page 166: 186151
# Error for page 167: 203694
# Error for page 168: 238293
# Error for page 169: 185082
# Error for page 170: 111061
# Error for page 176: 238568
# Error for page 177: 206667
# Error for page 178: 196401
# Error for page 179: 227440
# Error for page 180: 167939
# Error for page 186: 128734
# Error for page 187: 253741
# Error for page 188: 223929
# Error for page 189: 233958
# Error for page 190: 186093
# Error for page 196: 225202
# Error for page 197: 123969
# Error for page 198: 260274
# Error for page 199: 215541
# Error for page 200: 175740
# Error for page 206: 237960
# Error for page 207: 215174
# Error for page 208: 214552
# Error for page 209: 201300
# Error for page 210: 176289
# Error for page 216: 237987
# Error for page 217: 200090
# Error for page 218: 191626
# Error for page 219: 262859
# Error for page 220: 205749
# Error for page 226: 217806
# Error for page 227: 231107
# Error for page 228: 212326
# Error for page 229: 249093
# Error for page 230: 119307
# Error for page 236: 190550
# Error for page 237: 184615
# Error for page 238: 174094
# Error for page 239: 290623
# Error for page 240: 128300
# Error for page 246: 256285
# Error for page 247: 274684
# Error for page 248: 199626
# Error for page 249: 198610
# Error for page 250: 209174
# Error for page 256: 220249
# Error for page 257: 287524
# Error for page 258: 182066
# Error for page 259: 241305
# Error for page 260: 242941
# Error for page 266: 234371
# Error for page 267: 232914
# Error for page 268: 287591
# Error for page 269: 200455
# Error for page 270: 215373
# Error for page 276: 192024
# Error for page 277: 237393
# Error for page 278: 250010
# Error for page 279: 234652
# Error for page 280: 210611
# Error for page 286: 222276
# Error for page 287: 221857
# Error for page 288: 199475
# Error for page 289: 241306
# Error for page 290: 243117
# Error for page 296: 244774
# Error for page 297: 301212
# Error for page 298: 217526
# Error for page 299: 179349
# Error for page 300: 187039
# Error for page 301: 253481
# Error for page 302: 257714
# Error for page 303: 216704
# Error for page 304: 220566
# Error for page 305: 173247
# Error for page 311: 272060
# Error for page 312: 292450
# Error for page 313: 278677
# Error for page 314: 203790
# Error for page 315: 212121
# Error for page 321: 208473
# Error for page 322: 231232
# Error for page 323: 210425
# Error for page 324: 226522
# Error for page 325: 168400
# Error for page 331: 236614
# Error for page 332: 223073
# Error for page 333: 201231
# Error for page 334: 215164
# Error for page 335: 180230
# Error for page 341: 232737
# Error for page 342: 245227
# Error for page 343: 254432
# Error for page 344: 237086
# Error for page 345: 160785
# Error for page 351: 258837
# Error for page 352: 271229
# Error for page 353: 214873
# Error for page 354: 201083
# Error for page 355: 241998
# Error for page 361: 224460
# Error for page 362: 266864
# Error for page 363: 229613
# Error for page 364: 250307
# Error for page 365: 204897
# Error for page 371: 201967
# Error for page 372: 253083
# Error for page 373: 151524
# Error for page 374: 231636
# Error for page 375: 210854
# Error for page 381: 246271
# Error for page 382: 229620
# Error for page 383: 266750
# Error for page 384: 247135
# Error for page 385: 207561
# Error for page 391: 227243
# Error for page 392: 242168
# Error for page 393: 216558
# Error for page 394: 178241
# Error for page 395: 217651
# Error for page 401: 232690
# Error for page 402: 207879
# Error for page 403: 197323
# Error for page 404: 243268
# Error for page 405: 188909
# Error for page 411: 282527
# Error for page 412: 207173
# Error for page 413: 236712
# Error for page 414: 194218
# Error for page 415: 210683
# Error for page 421: 230508
# Error for page 422: 237645
# Error for page 423: 211083
# Error for page 424: 223689
# Error for page 425: 205140
# Error for page 431: 257061
# Error for page 432: 157274
# Error for page 433: 218028
# Error for page 434: 221058
# Error for page 435: 201040
# Error for page 441: 196734
# Error for page 442: 226292
# Error for page 443: 236448
# Error for page 444: 263069
# Error for page 445: 189745
# [22, 35, 41, 96, 100, 113, 114, 4, 6, 7, 14, 17, 25, 44, 45, 49, 51, 59, 67, 76, 78, 127, 135, 2, 3, 9, 11, 18, 23, 27, 29, 31, 32, 37, 40, 43, 48, 50, 52, 53, 58, 60, 61, 63, 66, 71, 75, 79, 83, 87, 88, 91, 94, 97, 101, 102, 106, 109, 111, 115, 116, 118, 125, 126, 128, 130, 131, 132, 133, 134, 0, 5, 13, 16, 26, 28, 30, 33, 34, 39, 42, 55, 57, 62, 64, 68, 69, 70, 73, 74, 80, 81, 82, 84, 86, 89, 90, 92, 95, 99, 103, 107, 110, 117, 119, 120, 121, 123]
# Mean Error: 217339.47555555555
# Standard Deviation of Error: 34502.3484930851
