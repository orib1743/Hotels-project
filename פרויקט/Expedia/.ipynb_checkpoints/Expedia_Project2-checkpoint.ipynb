# %%
import numpy as np
import pandas as pd
import sklearn as sk
import sklearn.tree as tree
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime
from collections import Counter
import re

# %% [markdown]
# # <u>שלב 2</u>

# %% [markdown]
# ## איחוד הקבצים

# %%
import pandas as pd
import os

# יצירת רשימה לאחסון הקבצים
files = ['expedia_hotels_ny5.csv', 'expedia_hotels_ny3.csv' , 'expedia_hotels_ny4.csv']

# יצירת רשימה ריקה לאחסון כל השורות
all_rows = []

# לולאה על כל קובץ ברשימת הקבצים
for file in files:
    # קריאת הקובץ
    df = pd.read_csv(file)
    # הוספת עמודה עם שם הקובץ
    df['source_file'] = os.path.basename(file)
    # ניקוי סימון שח מעמודת מחיר ומחיר לפני הנחה
    df['original_price'] = df['original_price'].replace('[$,]', '', regex=True).astype(float)
    #df['original_price'] = df['original_price'].fillna(0).astype(int)  # Handle NaNs before converting to int
    df['current_price'] = df['current_price'].replace('[$,]', '', regex=True).astype(float)
    df['breakfast'] = df['breakfast'].replace('Breakfast included', 'Yes')

    # הוספת השורות לרשימה
    all_rows.append(df)

# איחוד כל השורות לטבלה אחת
data = pd.concat(all_rows, ignore_index=True)

# יצירת קובץ CSV חדש עם הנתונים המאוחדים
data.to_csv('merged_expedia.csv', index=False)

# %% [markdown]
# # Exploration

# %%
data.head()
# Out:
#                                  name      neighborhood  current_price  \
# 0                                 NaN               NaN            NaN
# 1             Hyatt House Jersey City       Jersey City          227.0
# 2  Margaritaville Resort Times Square  Theater District          185.0
# 3                  Penny Williamsburg      Williamsburg          220.0
# 4       PUBLIC, an Ian Schrager hotel          New York          329.0
#
#    original_price reviews_desc num_reviews breakfast free_cancellation  \
# 0             NaN          NaN         NaN        No                No
# 1           252.0    Excellent       1,306       Yes                No
# 2             NaN    Wonderful       3,670        No                No
# 3           275.0  Exceptional         521        No               Yes
# 4             NaN         Very       2,625        No                No
#
#    rooms_left  grade fully_refundable reserve_now_pay_later price_after_taxes  \
# 0         NaN    NaN               No                    No               NaN
# 1         8.0   8.68               No                    No         265 total
# 2         NaN   9.29               No                    No         274 total
# 3         1.0   9.69              Yes                   Yes         292 total
# 4         NaN   8.28               No                    No         427 total
#
#   checkin_date checkout_date  TTT  LOS Snapshot Date  order  \
# 0   08/07/2024    09/07/2024    1    1    07/07/2024      1
# 1   08/07/2024    09/07/2024    1    1    07/07/2024      2
# 2   08/07/2024    09/07/2024    1    1    07/07/2024      3
# 3   08/07/2024    09/07/2024    1    1    07/07/2024      4
# 4   08/07/2024    09/07/2024    1    1    07/07/2024      5
#
#               source_file
# 0  expedia_hotels_ny5.csv
# 1  expedia_hotels_ny5.csv
# 2  expedia_hotels_ny5.csv
# 3  expedia_hotels_ny5.csv
# 4  expedia_hotels_ny5.csv

# %%
data.sample()
# Out:
#                                              name      neighborhood  \
# 51219  Motto By Hilton New York City Times Square  Theater District
#
#        current_price  original_price reviews_desc num_reviews breakfast  \
# 51219          217.0           255.0    Wonderful         898        No
#
#       free_cancellation  rooms_left  grade fully_refundable  \
# 51219               Yes         NaN   9.09              Yes
#
#       reserve_now_pay_later price_after_taxes checkin_date checkout_date  TTT  \
# 51219                   Yes       1,433 total   13/07/2024    18/07/2024    7
#
#        LOS Snapshot Date  order             source_file
# 51219    5    06/07/2024     35  expedia_hotels_ny4.csv

# %%
unique_column = 'order'

# יצירת רשימת העמודות לבדיקה, מבלי לכלול את העמודה הייחודית
columns_to_check = data.columns.difference([unique_column])

# הסרת שורות כפולות
original_rows = data.shape[0]

# הסרת שורות כפולות
df_unique = data.drop_duplicates(subset=columns_to_check, keep='first')

# מספר השורות לאחר הסרת הכפילויות
new_rows = df_unique.shape[0]

# הצגת הדאטהפריים לאחר הסרת הכפילויות
print(f"\nNumber of rows removed: {original_rows - new_rows}")
# Out:
# DataFrame after removing duplicates:
#
# Number of rows removed: 3298

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67950 entries, 0 to 67949
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   67162 non-null  object
#  1   neighborhood           67497 non-null  object
#  2   current_price          67500 non-null  float64
#  3   original_price         32431 non-null  float64
#  4   reviews_desc           66992 non-null  object
#  5   num_reviews            67498 non-null  object
#  6   breakfast              67950 non-null  object
#  7   free_cancellation      67950 non-null  object
#  8   rooms_left             23090 non-null  float64
#  9   grade                  67415 non-null  float64
#  10  fully_refundable       67950 non-null  object
#  11  reserve_now_pay_later  67950 non-null  object
#  12  price_after_taxes      67500 non-null  object
#  13  checkin_date           67950 non-null  object
#  14  checkout_date          67950 non-null  object
#  15  TTT                    67950 non-null  int64
#  16  LOS                    67950 non-null  int64
#  17  Snapshot Date          67950 non-null  object
#  18  order                  67950 non-null  int64
#  19  source_file            67950 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 10.4+ MB

# %%
# טיפול בשדות של הדטה
# הפונקציה להמרת המחרוזת לתאריך
def convert_to_date(date_str):
    return datetime.strptime(date_str, '%d/%m/%Y')

# החלת הפונקציה על עמודת 'checkin_date'
data['checkin_date'] = data['checkin_date'].apply(convert_to_date)
data['checkout_date'] = data['checkout_date'].apply(convert_to_date)
data['Snapshot Date'] = data['Snapshot Date'].apply(convert_to_date)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67950 entries, 0 to 67949
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   67162 non-null  object
#  1   neighborhood           67497 non-null  object
#  2   current_price          67500 non-null  float64
#  3   original_price         32431 non-null  float64
#  4   reviews_desc           66992 non-null  object
#  5   num_reviews            67498 non-null  object
#  6   breakfast              67950 non-null  object
#  7   free_cancellation      67950 non-null  object
#  8   rooms_left             23090 non-null  float64
#  9   grade                  67415 non-null  float64
#  10  fully_refundable       67950 non-null  object
#  11  reserve_now_pay_later  67950 non-null  object
#  12  price_after_taxes      67500 non-null  object
#  13  checkin_date           67950 non-null  datetime64[ns]
#  14  checkout_date          67950 non-null  datetime64[ns]
#  15  TTT                    67950 non-null  int64
#  16  LOS                    67950 non-null  int64
#  17  Snapshot Date          67950 non-null  datetime64[ns]
#  18  order                  67950 non-null  int64
#  19  source_file            67950 non-null  object
# dtypes: datetime64[ns](3), float64(4), int64(3), object(10)
# memory usage: 10.4+ MB

# %% [markdown]
# ### תיקון הנתונים והמרה למשתנה נומרי

# %%
# Clean the 'price_after_taxes' column
data['price_after_taxes'] = data['price_after_taxes'].str.replace(r'\D', '', regex=True)

# Convert the cleaned column to numeric
data['price_after_taxes'] = pd.to_numeric(data['price_after_taxes'], errors='coerce')

# Convert 'num_reviews' column to numeric
data['num_reviews'] = data['num_reviews'].str.replace(',', '').astype(float)

# %%
print(data['num_reviews'].dtype)
# Out:
# float64

# %%
print(data['price_after_taxes'].dtype)
# Out:
# float64

# %%
data.head()
# Out:
#                                  name      neighborhood  current_price  \
# 0                                 NaN               NaN            NaN
# 1             Hyatt House Jersey City       Jersey City          227.0
# 2  Margaritaville Resort Times Square  Theater District          185.0
# 3                  Penny Williamsburg      Williamsburg          220.0
# 4       PUBLIC, an Ian Schrager hotel          New York          329.0
#
#    original_price reviews_desc  num_reviews breakfast free_cancellation  \
# 0             NaN          NaN          NaN        No                No
# 1           252.0    Excellent       1306.0       Yes                No
# 2             NaN    Wonderful       3670.0        No                No
# 3           275.0  Exceptional        521.0        No               Yes
# 4             NaN         Very       2625.0        No                No
#
#    rooms_left  grade fully_refundable reserve_now_pay_later  \
# 0         NaN    NaN               No                    No
# 1         8.0   8.68               No                    No
# 2         NaN   9.29               No                    No
# 3         1.0   9.69              Yes                   Yes
# 4         NaN   8.28               No                    No
#
#    price_after_taxes checkin_date checkout_date  TTT  LOS Snapshot Date  \
# 0                NaN   2024-07-08    2024-07-09    1    1    2024-07-07
# 1              265.0   2024-07-08    2024-07-09    1    1    2024-07-07
# 2              274.0   2024-07-08    2024-07-09    1    1    2024-07-07
# 3              292.0   2024-07-08    2024-07-09    1    1    2024-07-07
# 4              427.0   2024-07-08    2024-07-09    1    1    2024-07-07
#
#    order             source_file
# 0      1  expedia_hotels_ny5.csv
# 1      2  expedia_hotels_ny5.csv
# 2      3  expedia_hotels_ny5.csv
# 3      4  expedia_hotels_ny5.csv
# 4      5  expedia_hotels_ny5.csv

# %%
#  NULLבדיקת ערכי 
data.isnull().sum()
# Out:
# name                       788
# neighborhood               453
# current_price              450
# original_price           35519
# reviews_desc               958
# num_reviews                452
# breakfast                    0
# free_cancellation            0
# rooms_left               44860
# grade                      535
# fully_refundable             0
# reserve_now_pay_later        0
# price_after_taxes          450
# checkin_date                 0
# checkout_date                0
# TTT                          0
# LOS                          0
# Snapshot Date                0
# order                        0
# source_file                  0
# dtype: int64

# %%
# הסרת עמודות שרובן null
data = data.drop(['rooms_left'], axis=1)
data = data.drop(['original_price'], axis=1)

# הסרת null 
data = data[data['neighborhood'].notna()]
data = data[data['reviews_desc'].notna()]
data = data[data['price_after_taxes'].notna()]
data = data[data['name'].notna()] # לבדוק את הקובץ, זה לא הגיוני

# %%
# טיפול בשדות עם מעט ערכים חסרים ומילוי ערכי NULL בערך החציוני
data['grade'] = data['grade'].fillna(data['grade'].median())
data['num_reviews'] = data['num_reviews'].fillna(data['num_reviews'].median())

# הורשת שדה מיותר שהופנו לבדיקת איחוד הקבצים
data = data.drop(['source_file'], axis=1)

# %%
data.isnull().sum()
# Out:
# name                     0
# neighborhood             0
# current_price            0
# reviews_desc             0
# num_reviews              0
# breakfast                0
# free_cancellation        0
# grade                    0
# fully_refundable         0
# reserve_now_pay_later    0
# price_after_taxes        0
# checkin_date             0
# checkout_date            0
# TTT                      0
# LOS                      0
# Snapshot Date            0
# order                    0
# dtype: int64

# %% [markdown]
# # הכפלת מחיר ללילה בLOS עבור מחיר לכל השהייה

# %%
data['price'] = data['price_after_taxes'] * data['LOS']

data.head()
# Out:
#                                  name      neighborhood  current_price  \
# 1             Hyatt House Jersey City       Jersey City          227.0
# 2  Margaritaville Resort Times Square  Theater District          185.0
# 3                  Penny Williamsburg      Williamsburg          220.0
# 4       PUBLIC, an Ian Schrager hotel          New York          329.0
# 5               Radio City Apartments  Theater District          127.0
#
#   reviews_desc  num_reviews breakfast free_cancellation  grade  \
# 1    Excellent       1306.0       Yes                No   8.68
# 2    Wonderful       3670.0        No                No   9.29
# 3  Exceptional        521.0        No               Yes   9.69
# 4         Very       2625.0        No                No   8.28
# 5    Excellent       3586.0        No                No   8.88
#
#   fully_refundable reserve_now_pay_later  price_after_taxes checkin_date  \
# 1               No                    No              265.0   2024-07-08
# 2               No                    No              274.0   2024-07-08
# 3              Yes                   Yes              292.0   2024-07-08
# 4               No                    No              427.0   2024-07-08
# 5               No                    No              150.0   2024-07-08
#
#   checkout_date  TTT  LOS Snapshot Date  order  price
# 1    2024-07-09    1    1    2024-07-07      2  265.0
# 2    2024-07-09    1    1    2024-07-07      3  274.0
# 3    2024-07-09    1    1    2024-07-07      4  292.0
# 4    2024-07-09    1    1    2024-07-07      5  427.0
# 5    2024-07-09    1    1    2024-07-07      6  150.0

# %% [markdown]
# # גרפים מבוקשים

# %% [markdown]
# ## גרף מספר ביקורות

# %%
plt.figure(figsize=(10,6))
plt.hist(data['num_reviews'], bins=20, edgecolor='black')
plt.title('Distribution of num_reviews')
plt.xlabel('Num of Reviews')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## גרף ציונים

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['grade'], bins=20, edgecolor='black')
plt.title('Distribution of grades')
plt.xlabel('Grade')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## גרף מחירים

# %% [markdown]
# ### חילוק השכונות לפי מחיר ממוצע

# %% [markdown]
# ## גרף מחירים

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['price'].dropna(), bins=30, edgecolor='black')
plt.title('Distribution of Hotel Prices')
plt.xlabel('Price ($)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## ביצוע outlier על פי שיטת Tukey ( IQR1.5 )

# %%
print(data['price'].dtype)
# Out:
# float64

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data['price'].quantile(0.25)
Q3 = data['price'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Determine the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
data_new = data[(data['price'] >= lower_bound) & (data['price'] <= upper_bound)]

# Display the number of removed outliers
num_outliers = data.shape[0] - data_new.shape[0]
num_outliers
# Out:
# 624

# %%
data=data_new
data
# Out:
#                                                     name      neighborhood  \
# 1                                Hyatt House Jersey City       Jersey City
# 2                     Margaritaville Resort Times Square  Theater District
# 3                                     Penny Williamsburg      Williamsburg
# 4                          PUBLIC, an Ian Schrager hotel          New York
# 5                                  Radio City Apartments  Theater District
# ...                                                  ...               ...
# 67945                              The Solita Soho Hotel          New York
# 67946  InterContinental New York Times Square, an IHG...          New York
# 67947                           Pestana CR7 Times Square          New York
# 67948                                 East Village Hotel          New York
# 67949                   Cambria Hotel New York - Chelsea           Chelsea
#
#        current_price reviews_desc  num_reviews breakfast free_cancellation  \
# 1              227.0    Excellent       1306.0       Yes                No
# 2              185.0    Wonderful       3670.0        No                No
# 3              220.0  Exceptional        521.0        No               Yes
# 4              329.0         Very       2625.0        No                No
# 5              127.0    Excellent       3586.0        No                No
# ...              ...          ...          ...       ...               ...
# 67945          170.0         Good       1004.0        No               Yes
# 67946          300.0         Very       1068.0        No                No
# 67947          194.0    Excellent        678.0        No               Yes
# 67948          203.0         Very        652.0        No               Yes
# 67949          224.0    Excellent       1001.0        No                No
#
#        grade fully_refundable reserve_now_pay_later  price_after_taxes  \
# 1       8.68               No                    No              265.0
# 2       9.29               No                    No              274.0
# 3       9.69              Yes                   Yes              292.0
# 4       8.28               No                    No              427.0
# 5       8.88               No                    No              150.0
# ...      ...              ...                   ...                ...
# 67945   7.87              Yes                    No             1110.0
# 67946   8.48               No                    No             1940.0
# 67947   8.88              Yes                   Yes             1265.0
# 67948   8.28              Yes                    No             1302.0
# 67949   8.68               No                    No             1300.0
#
#       checkin_date checkout_date  TTT  LOS Snapshot Date  order   price
# 1       2024-07-08    2024-07-09    1    1    2024-07-07      2   265.0
# 2       2024-07-08    2024-07-09    1    1    2024-07-07      3   274.0
# 3       2024-07-08    2024-07-09    1    1    2024-07-07      4   292.0
# 4       2024-07-08    2024-07-09    1    1    2024-07-07      5   427.0
# 5       2024-07-08    2024-07-09    1    1    2024-07-07      6   150.0
# ...            ...           ...  ...  ...           ...    ...     ...
# 67945   2024-08-04    2024-08-09   29    5    2024-07-06    151  5550.0
# 67946   2024-08-04    2024-08-09   29    5    2024-07-06    152  9700.0
# 67947   2024-08-04    2024-08-09   29    5    2024-07-06    153  6325.0
# 67948   2024-08-04    2024-08-09   29    5    2024-07-06    154  6510.0
# 67949   2024-08-04    2024-08-09   29    5    2024-07-06    155  6500.0
#
# [66033 rows x 18 columns]

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# ## טיפול בשדה "תיאור ציון" והמרתו לשדה של יחס סדר

# %%
unique_grades = data['reviews_desc'].unique()
unique_grades
# Out:
# array(['Excellent', 'Wonderful', 'Exceptional', 'Very', 'Good'],
#       dtype=object)

# %%
data['reviews_desc'].value_counts()
# Out:
# reviews_desc
# Excellent      21621
# Wonderful      17051
# Very           15236
# Good            7058
# Exceptional     5067
# Name: count, dtype: int64

# %%
def get_average_grade_for_keywords(row, keyword):
    if pd.isna(row['reviews_desc']) or not isinstance(row['reviews_desc'], str):
        return None
    if keyword in row['reviews_desc']:
        return row['grade']
    return None

# Apply the function to get grades based on keywords
grades_by_keyword = []
for keyword in unique_grades:
    keyword_grades = data.apply(lambda row: get_average_grade_for_keywords(row, keyword), axis=1)
    keyword_grades = keyword_grades.dropna()
    if not keyword_grades.empty:
        avg_grade = keyword_grades.mean()
        grades_by_keyword.append((keyword, avg_grade))

# Sort keywords by average price
grades_by_keyword.sort(key=lambda x: x[1], reverse=True)
grades_by_keyword
# Out:
# [('Exceptional', 9.620507203473457),
#  ('Wonderful', 9.190580611107851),
#  ('Excellent', 8.787728597197171),
#  ('Very', 8.262554476240483),
#  ('Good', 7.573428733352224)]

# %%
keyword_priority = {keyword: 5 - idx for idx, (keyword, _) in enumerate(grades_by_keyword)}

# Ensure we have up to 5 priorities
for idx in range(len(keyword_priority), 5):
    keyword_priority[f'Other_{5 - idx}'] = 5 - idx

keyword_priority
# Out:
# {'Exceptional': 5, 'Wonderful': 4, 'Excellent': 3, 'Very': 2, 'Good': 1}

# %%
# Define a function to map room type to priority
def map_room_type_to_priority(reviews_desc):
    if isinstance(reviews_desc, (int, int)):  # Skip if already a number
        return reviews_desc
    if pd.isna(reviews_desc) or not isinstance(reviews_desc, str):
        return 0  # Default priority for NaN values or non-string types
    for keyword, priority in keyword_priority.items():
        if keyword in reviews_desc:
            return priority
    return 0  # Default priority for unlisted types

# Apply the mapping to the reviews_desc column using .loc to avoid SettingWithCopyWarning
data.loc[:, 'reviews_desc'] = data['reviews_desc'].apply(map_room_type_to_priority)

# Display the updated dataframe
data.head()
# Out:
#                                  name      neighborhood  current_price  \
# 1             Hyatt House Jersey City       Jersey City          227.0
# 2  Margaritaville Resort Times Square  Theater District          185.0
# 3                  Penny Williamsburg      Williamsburg          220.0
# 4       PUBLIC, an Ian Schrager hotel          New York          329.0
# 5               Radio City Apartments  Theater District          127.0
#
#   reviews_desc  num_reviews breakfast free_cancellation  grade  \
# 1            3       1306.0       Yes                No   8.68
# 2            4       3670.0        No                No   9.29
# 3            5        521.0        No               Yes   9.69
# 4            2       2625.0        No                No   8.28
# 5            3       3586.0        No                No   8.88
#
#   fully_refundable reserve_now_pay_later  price_after_taxes checkin_date  \
# 1               No                    No              265.0   2024-07-08
# 2               No                    No              274.0   2024-07-08
# 3              Yes                   Yes              292.0   2024-07-08
# 4               No                    No              427.0   2024-07-08
# 5               No                    No              150.0   2024-07-08
#
#   checkout_date  TTT  LOS Snapshot Date  order  price
# 1    2024-07-09    1    1    2024-07-07      2  265.0
# 2    2024-07-09    1    1    2024-07-07      3  274.0
# 3    2024-07-09    1    1    2024-07-07      4  292.0
# 4    2024-07-09    1    1    2024-07-07      5  427.0
# 5    2024-07-09    1    1    2024-07-07      6  150.0

# %%
data['reviews_desc'].value_counts()
# Out:
# reviews_desc
# 3    21621
# 4    17051
# 2    15236
# 1     7058
# 5     5067
# Name: count, dtype: int64

# %% [markdown]
# ## המרת משתנים בעלי אופי נומינלי או קטגורי באמצעות מספר עמודות

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66033 entries, 1 to 67949
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   66033 non-null  object
#  1   neighborhood           66033 non-null  object
#  2   current_price          66033 non-null  float64
#  3   reviews_desc           66033 non-null  object
#  4   num_reviews            66033 non-null  float64
#  5   breakfast              66033 non-null  object
#  6   free_cancellation      66033 non-null  object
#  7   grade                  66033 non-null  float64
#  8   fully_refundable       66033 non-null  object
#  9   reserve_now_pay_later  66033 non-null  object
#  10  price_after_taxes      66033 non-null  float64
#  11  checkin_date           66033 non-null  datetime64[ns]
#  12  checkout_date          66033 non-null  datetime64[ns]
#  13  TTT                    66033 non-null  int64
#  14  LOS                    66033 non-null  int64
#  15  Snapshot Date          66033 non-null  datetime64[ns]
#  16  order                  66033 non-null  int64
#  17  price                  66033 non-null  float64
# dtypes: datetime64[ns](3), float64(5), int64(3), object(7)
# memory usage: 9.6+ MB

# %%
data['breakfast'].replace({'No':0,'Yes':1},inplace=True)
data['free_cancellation'].replace({'No':0,'Yes':1},inplace=True)
data['fully_refundable'].replace({'No':0,'Yes':1},inplace=True)
data['reserve_now_pay_later'].replace({'No':0,'Yes':1},inplace=True)

# %%
data.head()
# Out:
#                                  name      neighborhood  current_price  \
# 1             Hyatt House Jersey City       Jersey City          227.0
# 2  Margaritaville Resort Times Square  Theater District          185.0
# 3                  Penny Williamsburg      Williamsburg          220.0
# 4       PUBLIC, an Ian Schrager hotel          New York          329.0
# 5               Radio City Apartments  Theater District          127.0
#
#   reviews_desc  num_reviews  breakfast  free_cancellation  grade  \
# 1            3       1306.0          1                  0   8.68
# 2            4       3670.0          0                  0   9.29
# 3            5        521.0          0                  1   9.69
# 4            2       2625.0          0                  0   8.28
# 5            3       3586.0          0                  0   8.88
#
#    fully_refundable  reserve_now_pay_later  price_after_taxes checkin_date  \
# 1                 0                      0              265.0   2024-07-08
# 2                 0                      0              274.0   2024-07-08
# 3                 1                      1              292.0   2024-07-08
# 4                 0                      0              427.0   2024-07-08
# 5                 0                      0              150.0   2024-07-08
#
#   checkout_date  TTT  LOS Snapshot Date  order  price
# 1    2024-07-09    1    1    2024-07-07      2  265.0
# 2    2024-07-09    1    1    2024-07-07      3  274.0
# 3    2024-07-09    1    1    2024-07-07      4  292.0
# 4    2024-07-09    1    1    2024-07-07      5  427.0
# 5    2024-07-09    1    1    2024-07-07      6  150.0

# %%
# בדיקת היקף הערכים של 1 והאם צריך להוריד את העמודה
data['breakfast'].value_counts()
# Out:
# breakfast
# 0    57687
# 1     8346
# Name: count, dtype: int64

# %%
# בדיקת היקף הערכים של 1 והאם צריך להוריד את העמודה
data['free_cancellation'].value_counts()
# Out:
# free_cancellation
# 0    35096
# 1    30937
# Name: count, dtype: int64

# %%
# בדיקת היקף הערכים של 1 והאם צריך להוריד את העמודה
data['fully_refundable'].value_counts()
# Out:
# fully_refundable
# 0    35096
# 1    30937
# Name: count, dtype: int64

# %%
# בדיקת היקף הערכים של 1 והאם צריך להוריד את העמודה
data['reserve_now_pay_later'].value_counts()
# Out:
# reserve_now_pay_later
# 0    43060
# 1    22973
# Name: count, dtype: int64

# %%
data = pd.get_dummies(data,columns=['neighborhood'])
data.columns
# Out:
# Index(['name', 'current_price', 'reviews_desc', 'num_reviews', 'breakfast',
#        'free_cancellation', 'grade', 'fully_refundable',
#        'reserve_now_pay_later', 'price_after_taxes', 'checkin_date',
#        'checkout_date', 'TTT', 'LOS', 'Snapshot Date', 'order', 'price',
#        'neighborhood_Bronx', 'neighborhood_Brooklyn',
#        'neighborhood_Central New York City', 'neighborhood_Chelsea',
#        'neighborhood_Downtown Brooklyn', 'neighborhood_Entire home',
#        'neighborhood_Flushing', 'neighborhood_Greenwich Village',
#        'neighborhood_Harlem', 'neighborhood_Jamaica',
#        'neighborhood_Jersey City', 'neighborhood_Long Island City',
#        'neighborhood_New York', 'neighborhood_Queens', 'neighborhood_SoHo',
#        'neighborhood_Theater District', 'neighborhood_Upper West Side',
#        'neighborhood_Williamsburg'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['name', 'current_price', 'reviews_desc', 'num_reviews', 'breakfast',
#        'free_cancellation', 'grade', 'fully_refundable',
#        'reserve_now_pay_later', 'price_after_taxes', 'checkin_date',
#        'checkout_date', 'TTT', 'LOS', 'Snapshot Date', 'order', 'price',
#        'neighborhood_Bronx', 'neighborhood_Brooklyn',
#        'neighborhood_Central New York City', 'neighborhood_Chelsea',
#        'neighborhood_Downtown Brooklyn', 'neighborhood_Entire home',
#        'neighborhood_Flushing', 'neighborhood_Greenwich Village',
#        'neighborhood_Harlem', 'neighborhood_Jamaica',
#        'neighborhood_Jersey City', 'neighborhood_Long Island City',
#        'neighborhood_New York', 'neighborhood_Queens', 'neighborhood_SoHo',
#        'neighborhood_Theater District', 'neighborhood_Upper West Side',
#        'neighborhood_Williamsburg'],
#       dtype='object')

# %% [markdown]
# # בחינת הנתונים

# %%
data.describe()
# Out:
#        current_price   num_reviews     breakfast  free_cancellation  \
# count   66033.000000  66033.000000  66033.000000       66033.000000
# mean      257.643421   1459.839050      0.126391           0.468508
# min        70.000000      1.000000      0.000000           0.000000
# 25%       211.000000   1002.000000      0.000000           0.000000
# 50%       241.000000   1052.000000      0.000000           0.000000
# 75%       284.000000   1651.000000      0.000000           1.000000
# max      1264.000000   5946.000000      1.000000           1.000000
# std        79.459810   1019.790971      0.332292           0.499011
#
#               grade  fully_refundable  reserve_now_pay_later  \
# count  66033.000000      66033.000000           66033.000000
# mean       8.704689          0.468508               0.347902
# min        7.070000          0.000000               0.000000
# 25%        8.280000          0.000000               0.000000
# 50%        8.880000          0.000000               0.000000
# 75%        9.090000          1.000000               1.000000
# max        9.890000          1.000000               1.000000
# std        0.573711          0.499011               0.476308
#
#        price_after_taxes                   checkin_date  \
# count       66033.000000                          66033
# mean          947.597610  2024-07-21 05:29:05.618099968
# min           128.000000            2024-07-06 00:00:00
# 25%           532.000000            2024-07-14 00:00:00
# 50%           912.000000            2024-07-21 00:00:00
# 75%          1302.000000            2024-07-29 00:00:00
# max          3668.000000            2024-08-06 00:00:00
# std           508.016037                            NaN
#
#                        checkout_date           TTT           LOS  \
# count                          66033  66033.000000  66033.000000
# mean   2024-07-24 04:58:32.498296320     15.228386      2.978783
# min              2024-07-07 00:00:00      0.000000      1.000000
# 25%              2024-07-17 00:00:00      8.000000      2.000000
# 50%              2024-07-24 00:00:00     15.000000      3.000000
# 75%              2024-08-01 00:00:00     23.000000      4.000000
# max              2024-08-11 00:00:00     30.000000      5.000000
# std                              NaN      8.663024      1.407920
#
#                        Snapshot Date         order         price
# count                          66033  66033.000000  66033.000000
# mean   2024-07-06 00:00:13.084366848     78.087063   3435.738464
# min              2024-07-05 00:00:00      2.000000    128.000000
# 25%              2024-07-05 00:00:00     40.000000   1040.000000
# 50%              2024-07-06 00:00:00     78.000000   2691.000000
# 75%              2024-07-07 00:00:00    116.000000   5500.000000
# max              2024-07-07 00:00:00    155.000000  12440.000000
# std                              NaN     43.453095   2831.404751

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66033 entries, 1 to 67949
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   name                                66033 non-null  object
#  1   current_price                       66033 non-null  float64
#  2   reviews_desc                        66033 non-null  object
#  3   num_reviews                         66033 non-null  float64
#  4   breakfast                           66033 non-null  int64
#  5   free_cancellation                   66033 non-null  int64
#  6   grade                               66033 non-null  float64
#  7   fully_refundable                    66033 non-null  int64
#  8   reserve_now_pay_later               66033 non-null  int64
#  9   price_after_taxes                   66033 non-null  float64
#  10  checkin_date                        66033 non-null  datetime64[ns]
#  11  checkout_date                       66033 non-null  datetime64[ns]
#  12  TTT                                 66033 non-null  int64
#  13  LOS                                 66033 non-null  int64
#  14  Snapshot Date                       66033 non-null  datetime64[ns]
#  15  order                               66033 non-null  int64
#  16  price                               66033 non-null  float64
#  17  neighborhood_Bronx                  66033 non-null  bool
#  18  neighborhood_Brooklyn               66033 non-null  bool
#  19  neighborhood_Central New York City  66033 non-null  bool
#  20  neighborhood_Chelsea                66033 non-null  bool
#  21  neighborhood_Downtown Brooklyn      66033 non-null  bool
#  22  neighborhood_Entire home            66033 non-null  bool
#  23  neighborhood_Flushing               66033 non-null  bool
#  24  neighborhood_Greenwich Village      66033 non-null  bool
#  25  neighborhood_Harlem                 66033 non-null  bool
#  26  neighborhood_Jamaica                66033 non-null  bool
#  27  neighborhood_Jersey City            66033 non-null  bool
#  28  neighborhood_Long Island City       66033 non-null  bool
#  29  neighborhood_New York               66033 non-null  bool
#  30  neighborhood_Queens                 66033 non-null  bool
#  31  neighborhood_SoHo                   66033 non-null  bool
#  32  neighborhood_Theater District       66033 non-null  bool
#  33  neighborhood_Upper West Side        66033 non-null  bool
#  34  neighborhood_Williamsburg           66033 non-null  bool
# dtypes: bool(18), datetime64[ns](3), float64(5), int64(7), object(2)
# memory usage: 10.2+ MB

# %%
# טעות בקלט - שכונה לא קיימת (יש שורה אחת)
data = data.drop(['neighborhood_Entire home'], axis=1)

# %%
corr_price = data[['current_price','reviews_desc','num_reviews','breakfast','free_cancellation','grade','fully_refundable','reserve_now_pay_later','price','TTT','LOS' ]].corr()['price']
corr_price.sort_values()
# Out:
# TTT                     -0.043265
# breakfast               -0.034294
# num_reviews              0.011168
# grade                    0.074193
# reviews_desc             0.080938
# free_cancellation        0.097858
# fully_refundable         0.097858
# reserve_now_pay_later    0.117111
# current_price            0.211724
# LOS                      0.923888
# price                    1.000000
# Name: price, dtype: float64

# %%
corr_price_loc = data[['neighborhood_Bronx', 'neighborhood_Brooklyn', 'neighborhood_Central New York City' ,'neighborhood_Downtown Brooklyn', 'neighborhood_Chelsea', 'neighborhood_Flushing' , 'neighborhood_Harlem','neighborhood_Greenwich Village','neighborhood_Jamaica','neighborhood_Jersey City','neighborhood_Long Island City',  'neighborhood_New York','neighborhood_Queens' ,'neighborhood_SoHo', 'neighborhood_Theater District', 'neighborhood_Upper West Side' , 'neighborhood_Williamsburg','price']].corr()['price']
corr_price_loc.sort_values()
# Out:
# neighborhood_New York                -0.063813
# neighborhood_Queens                  -0.041212
# neighborhood_Long Island City        -0.019773
# neighborhood_Brooklyn                -0.018186
# neighborhood_Downtown Brooklyn       -0.013566
# neighborhood_SoHo                    -0.012725
# neighborhood_Greenwich Village       -0.009889
# neighborhood_Flushing                -0.006773
# neighborhood_Jersey City             -0.006142
# neighborhood_Chelsea                 -0.004542
# neighborhood_Bronx                   -0.003653
# neighborhood_Jamaica                 -0.001382
# neighborhood_Upper West Side          0.006207
# neighborhood_Harlem                   0.014021
# neighborhood_Williamsburg             0.016944
# neighborhood_Central New York City    0.033180
# neighborhood_Theater District         0.080243
# price                                 1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,8))
mask = np.array(data[['reviews_desc','num_reviews','breakfast','free_cancellation','grade','fully_refundable','reserve_now_pay_later','price','TTT','LOS', 'current_price' ]].corr())
mask[np.tril_indices_from(mask)] = False
sns.heatmap(data[['reviews_desc','num_reviews','breakfast','free_cancellation','grade','fully_refundable','reserve_now_pay_later','price','TTT','LOS', 'current_price' ]].corr(), annot=True, cmap='RdYlGn', mask=mask, vmax=0.8, square=True)
# Out:
# <Axes: >

# %% [markdown]
# # Create the PairGrid

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data[['current_price','reviews_desc','num_reviews','breakfast','free_cancellation','grade','fully_refundable','reserve_now_pay_later','price','TTT','LOS']], figsize=(20,10), alpha=0.1, diagonal='kde')
plt.show()

# %%
data.columns
# Out:
# Index(['name', 'current_price', 'reviews_desc', 'num_reviews', 'breakfast',
#        'free_cancellation', 'grade', 'fully_refundable',
#        'reserve_now_pay_later', 'price_after_taxes', 'checkin_date',
#        'checkout_date', 'TTT', 'LOS', 'Snapshot Date', 'order', 'price',
#        'neighborhood_Bronx', 'neighborhood_Brooklyn',
#        'neighborhood_Central New York City', 'neighborhood_Chelsea',
#        'neighborhood_Downtown Brooklyn', 'neighborhood_Flushing',
#        'neighborhood_Greenwich Village', 'neighborhood_Harlem',
#        'neighborhood_Jamaica', 'neighborhood_Jersey City',
#        'neighborhood_Long Island City', 'neighborhood_New York',
#        'neighborhood_Queens', 'neighborhood_SoHo',
#        'neighborhood_Theater District', 'neighborhood_Upper West Side',
#        'neighborhood_Williamsburg'],
#       dtype='object')

# %% [markdown]
# # תובנות מהגרפים

# %%
# שמירת הנתונים לקובץ CSV
data.to_csv('expedia_data.csv', index=False)
